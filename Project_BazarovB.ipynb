# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.utils import resample,shuffle
import re
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('train.csv')
train_df.tail()
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 9995    77          32    2.0  50.401785   30.476203            5.0      6
# 9996  6159          18    1.0  41.521546   20.539216            9.0     13
# 9997  5123          27    1.0  47.939008         NaN            1.0     12
# 9998  5400          75    2.0  43.602562   33.840147            8.0      1
# 9999  6306         128    1.0  38.666645   21.157874            8.0      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9995         5.0       1968   0.135650         B         B        46
# 9996        13.0       2000   0.000000         B         B        30
# 9997        16.0       2015   0.072158         B         B         2
# 9998         5.0       1961   0.307467         B         A        30
# 9999        17.0       1990   0.000000         B         B        27
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# ...

# %%
train_df.dtypes
# Out:
# Id                 int64
# DistrictId         int64
# Rooms            float64
# Square           float64
# LifeSquare       float64
# KitchenSquare    float64
# Floor              int64
# HouseFloor       float64
# HouseYear          int64
# Ecology_1        float64
# Ecology_2         object
# Ecology_3         object
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Healthcare_1     float64
# Helthcare_2        int64
# Shops_1            int64
# Shops_2           object
# Price            float64
# dtype: object

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %%
train_df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
train_df['Rooms'].value_counts()
# Out:
# 2.0     3880
# 1.0     3705
# 3.0     2235
# 4.0      150
# 5.0       18
# 0.0        8
# 10.0       2
# 19.0       1
# 6.0        1
# Name: Rooms, dtype: int64

# %%
y_train = pd.DataFrame(train_df, columns=["Price"])
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   10000 non-null  float64
# dtypes: float64(1)
# memory usage: 78.2 KB

# %%
y_train.tail()
# Out:
#               Price
# 9995  196684.316040
# 9996  189050.289571
# 9997  159143.805370
# 9998  181595.339808
# 9999  218714.077615

# %%
x_train = pd.DataFrame(train_df, columns=["Id","DistrictId","Rooms","Square","LifeSquare","KitchenSquare","Floor","HouseFloor","HouseYear","Ecology_1","Ecology_2","Ecology_3","Social_1","Social_2","Social_3","Healthcare_1","Helthcare_2","Shops_1","Shops_2" ])
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
train_df['Ecology_2'].value_counts()
# Out:
# B    9903
# A      97
# Name: Ecology_2, dtype: int64

# %%
train_df['Ecology_3'].value_counts()
# Out:
# B    9725
# A     275
# Name: Ecology_3, dtype: int64

# %%
train_df['Shops_2'].value_counts()
# Out:
# B    9175
# A     825
# Name: Shops_2, dtype: int64

# %%
binary_to_numbers = {'A': 0, 'B': 1}

# %%
def binary(x_train_):
    x_train['Ecology_2'] = x_train['Ecology_2'].replace(binary_to_numbers)
    x_train['Ecology_3'] = x_train['Ecology_3'].replace(binary_to_numbers)
    x_train['Shops_2'] = x_train['Shops_2'].replace(binary_to_numbers)
    return x_train_
dft = binary(x_train)

# %%
dft.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040          1          1        33      7976
# 1         9.0       1978   0.000070          1          1        46     10309
# 2        12.0       1968   0.049637          1          1        34      7759
# 3        17.0       1977   0.437885          1          1        23      5735
# 4        12.0       1976   0.012339          1          1        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2
# ...

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  int64
#  11  Ecology_3      10000 non-null  int64
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %%
dft['HouseYear'].value_counts()
# Out:
# 1977    2652
# 2017     308
# 2016     305
# 2015     299
# 2014     210
#         ...
# 4968       1
# 1914       1
# 1916       1
# 1910       1
# 1928       1
# Name: HouseYear, Length: 97, dtype: int64

# %%
dft['HouseYear'].sort_values(ascending = False)
# Out:
# 1497    20052011
# 4189        4968
# 5701        2020
# 2493        2020
# 1499        2020
#           ...
# 7611        1916
# 910         1914
# 2656        1912
# 5111        1912
# 9317        1910
# Name: HouseYear, Length: 10000, dtype: int64

# %%
dft.loc[dft['HouseYear'] > 2020, 'HouseYear'] = 2020

# %%
dft['HouseYear'].sort_values(ascending = False)
# Out:
# 5701    2020
# 4189    2020
# 2493    2020
# 1499    2020
# 3357    2020
#         ...
# 7611    1916
# 910     1914
# 2656    1912
# 5111    1912
# 9317    1910
# Name: HouseYear, Length: 10000, dtype: int64

# %%
dft['Healthcare_1'].value_counts()
# Out:
# 540.0     511
# 30.0      348
# 1046.0    245
# 750.0     163
# 229.0     148
#          ...
# 370.0      14
# 32.0       12
# 1815.0     10
# 35.0        2
# 0.0         1
# Name: Healthcare_1, Length: 79, dtype: int64

# %%
dft['Healthcare_1'].mean()
# Out:
# 1142.9044598231449

# %%
dft.loc[dft['Healthcare_1'].isnull(), 'Healthcare_1'] = dft['Healthcare_1'].mean()

# %%
dft.loc[dft['LifeSquare'].isnull(), 'LifeSquare'] = dft['LifeSquare'].mean()

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     10000 non-null  float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  int64
#  11  Ecology_3      10000 non-null  int64
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   10000 non-null  float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %%
test_df = pd.read_csv('test.csv')
test_df.tail()
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4995   8180          11    3.0  67.133911   50.809797            6.0      5
# 4996   4695           1    1.0  40.198472   21.807061           10.0     12
# 4997   5783          12    3.0  77.842178   48.282625            9.0     23
# 4998   4780          62    2.0  81.305222         NaN            0.0      4
# 4999  12504          30    2.0  60.555693         NaN            1.0     10
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4995         9.0       1973   0.000170         B         B        36
# 4996        17.0       2017   0.007122         B         B         1
# 4997        22.0       1989   0.090799         B         B        74
# 4998         0.0       1977   0.072158         B         B         2
# 4999        17.0       1977   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# ...

# %% [markdown]
# Нормализация тестовых данных

# %%
def binary(test_df_):
    test_df['Ecology_2'] = test_df['Ecology_2'].replace(binary_to_numbers)
    test_df['Ecology_3'] = test_df['Ecology_3'].replace(binary_to_numbers)
    test_df['Shops_2'] = test_df['Shops_2'].replace(binary_to_numbers)
    return test_df_
dft_test = binary(test_df)

# %%
test_df.tail()
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4995   8180          11    3.0  67.133911   50.809797            6.0      5
# 4996   4695           1    1.0  40.198472   21.807061           10.0     12
# 4997   5783          12    3.0  77.842178   48.282625            9.0     23
# 4998   4780          62    2.0  81.305222         NaN            0.0      4
# 4999  12504          30    2.0  60.555693         NaN            1.0     10
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 4995         9.0       1973   0.000170          1          1        36
# 4996        17.0       2017   0.007122          1          1         1
# 4997        22.0       1989   0.090799          1          1        74
# 4998         0.0       1977   0.072158          1          1         2
# 4999        17.0       1977   0.000078          1          1        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2
# ...

# %%
dft_test.loc[dft_test['HouseYear'] > 2020, 'HouseYear'] = 2020
dft_test.loc[dft_test['Healthcare_1'].isnull(), 'Healthcare_1'] = dft['Healthcare_1'].mean()
dft_test.loc[dft_test['LifeSquare'].isnull(), 'LifeSquare'] = dft['LifeSquare'].mean()

# %%
dft_test.tail()
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4995   8180          11    3.0  67.133911   50.809797            6.0      5
# 4996   4695           1    1.0  40.198472   21.807061           10.0     12
# 4997   5783          12    3.0  77.842178   48.282625            9.0     23
# 4998   4780          62    2.0  81.305222   37.199645            0.0      4
# 4999  12504          30    2.0  60.555693   37.199645            1.0     10
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 4995         9.0       1973   0.000170          1          1        36
# 4996        17.0       2017   0.007122          1          1         1
# 4997        22.0       1989   0.090799          1          1        74
# 4998         0.0       1977   0.072158          1          1         2
# 4999        17.0       1977   0.000078          1          1        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2
# ...

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     10000 non-null  float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  int64
#  11  Ecology_3      10000 non-null  int64
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   10000 non-null  float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %%
dft.tail()
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 9995    77          32    2.0  50.401785   30.476203            5.0      6
# 9996  6159          18    1.0  41.521546   20.539216            9.0     13
# 9997  5123          27    1.0  47.939008   37.199645            1.0     12
# 9998  5400          75    2.0  43.602562   33.840147            8.0      1
# 9999  6306         128    1.0  38.666645   21.157874            8.0      7
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 9995         5.0       1968   0.135650          1          1        46
# 9996        13.0       2000   0.000000          1          1        30
# 9997        16.0       2015   0.072158          1          1         2
# 9998         5.0       1961   0.307467          1          0        30
# 9999        17.0       1990   0.000000          1          1        27
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2
# ...

# %%
lr = LinearRegression()

# %% [markdown]
# # Обучаем модель с помощью линейной регрессии

# %%
lr.fit(dft, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(dft_test)

# %%
y_pred
# Out:
# array([[180417.99435242],
#        [210273.91658795],
#        [220090.22493222],
#        ...,
#        [357797.0354368 ],
#        [193500.68288314],
#        [226017.90771307]])

# %% [markdown]
# # Выгружаем данные

# %%
np.savetxt ("BBazarov_predictions.csv", y_pred, delimiter=" , ")
